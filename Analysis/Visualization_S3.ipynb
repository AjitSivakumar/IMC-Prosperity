# %% [markdown]
# Analysis for set price for Pearls at 10000 and Bananas at 4895

# %%
import pandas as pd
import numpy as np
import seaborn as sb

result = pd.read_csv("Analysis\\IMC_S3_Updated.csv", sep = ';')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[1], line 5
#       2 import numpy as np
#       3 import seaborn as sb
# ----> 5 result = pd.read_csv("Submissions\\IMC_S3_Updated.csv", sep = ';')
#
# File c:\Users\ajits\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\util\_decorators.py:211, in deprecate_kwarg.<locals>._deprecate_kwarg.<locals>.wrapper(*args, **kwargs)
#     209     else:
#     210         kwargs[new_arg_name] = new_arg_value
# --> 211 return func(*args, **kwargs)
#
# File c:\Users\ajits\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\util\_decorators.py:331, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     325 if len(args) > num_allow_args:
#     326     warnings.warn(
#     327         msg.format(arguments=_format_argument_list(allow_args)),
#     328         FutureWarning,
# ...

# %%
result
# Out:
#       day  timestamp  product  bid_price_1  bid_volume_1  bid_price_2  \
# 0      -1          0   PEARLS         9998             1       9995.0
# 1      -1          0  BANANAS         4893             1       4892.0
# 2      -1        100   PEARLS         9996             1       9995.0
# 3      -1        100  BANANAS         4892            31          NaN
# 4      -1        200  BANANAS         4892            22          NaN
# ...   ...        ...      ...          ...           ...          ...
# 3995   -1     199700   PEARLS        10002             1       9996.0
# 3996   -1     199800  BANANAS         4905            28          NaN
# 3997   -1     199800   PEARLS         9996             1       9995.0
# 3998   -1     199900  BANANAS         4906             6       4905.0
# 3999   -1     199900   PEARLS         9998             9       9995.0
#
#       bid_volume_2  bid_price_3  bid_volume_3  ask_price_1  ask_volume_1  \
# ...

# %%
bananas = result[result["product"] == "BANANAS"]
pearls = result[result["product"] == "PEARLS"]

# %%
sb.lineplot(data = bananas.profit_and_loss)
# Out:
# <Axes: ylabel='profit_and_loss'>

# %%
sb.lineplot(data = bananas.mid_price)
# Out:
# <Axes: ylabel='mid_price'>

# %%
sb.lineplot(data = pearls.profit_and_loss)
# Out:
# <Axes: ylabel='profit_and_loss'>

# %%
sb.lineplot(data = pearls.mid_price)
# Out:
# <Axes: ylabel='mid_price'>
